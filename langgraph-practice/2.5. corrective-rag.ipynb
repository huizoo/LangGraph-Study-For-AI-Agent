# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

embedding_function = OpenAIEmbeddings(model='text-embedding-3-large')

vector_store = Chroma(
    embedding_function=embedding_function,
    collection_name = 'income_tax_collection',
    persist_directory = './income_tax_collection'
)

retriever = vector_store.as_retriever(search_kwargs={'k': 3})

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph

class AgentState(TypedDict):
    query: str
    context: list
    answer: str

graph_builder = StateGraph(AgentState)

# %%
def retrieve(state: AgentState):
    query = state['query']
    docs = retriever.invoke(query)
    return {'context': docs}

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4o')

# %%
from langsmith import Client
from langchain_core.output_parsers import StrOutputParser
client = Client()

generate_prompt = client.pull_prompt("rlm/rag-prompt", dangerously_pull_public_prompt=True)
def generate(state: AgentState):
    context = state['context']
    query = state['query']
    rag_chain = generate_prompt | llm | StrOutputParser()
    response = rag_chain.invoke({'question': query, 'context': context})
    return {'answer': response}

# %%
from typing import Literal

doc_relevance_prompt = client.pull_prompt("langchain-ai/rag-document-relevance", dangerously_pull_public_prompt=True)

def check_doc_relevance(state: AgentState) -> Literal['relevant', 'irrelevant']:
    query = state['query']
    context = state['context']
    print(f'context == {context}')
    doc_relevance_chain = doc_relevance_prompt | llm
    response = doc_relevance_chain.invoke({'question': query, 'documents': context})
    print(f'doc relevance response: {response}')
    if response['Score'] == 1:
        return 'relevant'
    
    return 'irrelevant'

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

rewrite_prompt = PromptTemplate.from_template("""사용자의 질문을 보고, 웹 검색에 용이하게 사용자의 질문을 수정해주세요.
질문: {query}
""")

def rewrite(state: AgentState):
    query = state['query']
    rewrite_chain = rewrite_prompt | llm | StrOutputParser()

    response = rewrite_chain.invoke({'query': query})
    print(f'rewrite question == {response}')
    return {'query': response}

# %%
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch(
    max_results=3,
    search_depth="advanced",
    include_answer=True,
    include_raw_content=True,
    include_images=True,
)

def web_search(state: AgentState):
    query = state['query']
    results = tavily_search_tool.invoke(query)
    print(f'web search results == {results}')
    return {'context': results}

# %%
graph_builder.add_node('retrieve', retrieve)
graph_builder.add_node('generate', generate)
graph_builder.add_node('rewrite', rewrite)
graph_builder.add_node('web_search', web_search)

# %%
from langgraph.graph import START, END

graph_builder.add_edge(START, 'retrieve')
graph_builder.add_conditional_edges(
    'retrieve',
    check_doc_relevance,
    {
        'relevant': 'generate',
        'irrelevant': 'rewrite'
    }
)
graph_builder.add_edge('rewrite', 'web_search')
graph_builder.add_edge('web_search', 'generate')
graph_builder.add_edge('generate', END)

# %%
graph = graph_builder.compile()

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = {'query': '연봉 5천만원 거주자의 소득세는 얼마인가요?'}
graph.invoke(initial_state)
# Out:
# context == [Document(id='dae5d00d-ab30-4ff3-9434-63243526f05a', metadata={'source': './documents/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n│ 과세표준의 6개 구간 │\n|  세 율  |  과세표준 구간  |\n|----------|--------------------|\n│ 1,400만원 이하        │ 84만원 + (1,400만원을 초과하는 금액의 15%)  │\n│ 1,400만원 초과 ~ 5,000만원 이하 │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 5,000만원 초과 ~ 8,800만원 이하 │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 8,800만원 초과 ~ 1억5천만원 이하 │ 2,109만원 + (1억5천만원을 초과하는 금액의 38%)  │\n│ 1.5억원 초과 ~ 3억원 이하 │ 4,406만원 + (3억원을 초과하는 금액의 40%)  │\n│ 3억원 초과 │ 1억7,406만원 + (5억원을 초과하는 금액의 42%)  │'), Document(id='1d3b14c2-450c-4b35-a311-093c483d3f58', metadata={'source': './documents/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n│ 과세표준의 6개 구간 │\n|  세 율  |  과세표준 구간  |\n|----------|--------------------|\n│ 1,400만원 이하        │ 84만원 + (1,400만원을 초과하는 금액의 15%)  │\n│ 1,400만원 초과 ~ 5,000만원 이하 │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 5,000만원 초과 ~ 8,800만원 이하 │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 8,800만원 초과 ~ 1억5천만원 이하 │ 2,109만원 + (1억5천만원을 초과하는 금액의 38%)  │\n│ 1.5억원 초과 ~ 3억원 이하 │ 4,406만원 + (3억원을 초과하는 금액의 40%)  │\n│ 3억원 초과 │ 1억7,406만원 + (5억원을 초과하는 금액의 42%)  │'), Document(id='f774ea50-cd2b-4b5e-a0ee-350463b76045', metadata={'source': './documents/income_tax.txt'}, page_content='5년 이하: 30만원 → 납입연수\n5년 초과 10년 이하: 150만원 + 50만원 × (납입연수 - 5년)\n10년 초과 20년 이하: 400만원 + 80만원 × (납입연수 - 10년)\n20년 초과: 1,200만원 + 120만원 × (납입연수 - 20년)\n\n② 직장근로자 초과관세환급금을 분배하여 지급받는 경우 세액의 계산 방법 등 필요한 사항은 대통령령으로 정한다. \n<대통령 2014. 12. 23.>\n<전문개정 2009. 12. 31.>\n제64조(부동산매매업자에 대한 세액 계산의 특례)\n1) 대통령령으로 정하는 부동산매매업(이하 “부동산매매업”이라 한다)을 영위하는 거주자가 이하 “부동산매매업자”라 한다)로서 종합소득세법에 제104조제1항제1호(본항을 포함한다) 및 제103조 또는 같은 조 제7항 각 호의 어느 하나에 해당하는 자산의 매매자익(이하 “주택등매매차익”이라 한다)이 있는 자의 종합소득 산출세액은 다음 각 호의 세액 중 많은 것으로 한다. \n<개정 2014. 12. 23., 2017. 12. 19., 2020. 12. 29.>\n1. 종합소득 산출세액\n\n다음 각 목에 따른 세액의 합계액\n  가. 주택등매매차익에 따른 세율을 적용하여 산출한 세액의 합계액\n  나. 종합소득세법 제55조에 따라 주택등매매차익에 대한 개별세액을 공제한 금액을 과세표준으로 하고 이에 제55조에 따른 세율을 적용하여 산출세액')]
# doc relevance response: {'Score': 1, 'Explanation': "The FACTS provided contain multiple references to income tax calculations and relevant laws, including specific tax rates and thresholds, which are directly applicable to answering the QUESTION about calculating income tax for a resident with an annual income of 50 million won. Based on the description of the tax brackets such as '1,400만원 초과 ~ 5,000만원 이하' with a specific percentage for taxable income calculations, it is possible to determine the income tax owed by someone with an income of 50 million won. Therefore, the FACTS are relevant to the QUESTION because they provide the necessary information to calculate the income tax for a given income level."}
# {'query': '연봉 5천만원 거주자의 소득세는 얼마인가요?',
#  'context': [Document(id='dae5d00d-ab30-4ff3-9434-63243526f05a', metadata={'source': './documents/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n│ 과세표준의 6개 구간 │\n|  세 율  |  과세표준 구간  |\n|----------|--------------------|\n│ 1,400만원 이하        │ 84만원 + (1,400만원을 초과하는 금액의 15%)  │\n│ 1,400만원 초과 ~ 5,000만원 이하 │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 5,000만원 초과 ~ 8,800만원 이하 │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 8,800만원 초과 ~ 1억5천만원 이하 │ 2,109만원 + (1억5천만원을 초과하는 금액의 38%)  │\n│ 1.5억원 초과 ~ 3억원 이하 │ 4,406만원 + (3억원을 초과하는 금액의 40%)  │\n│ 3억원 초과 │ 1억7,406만원 + (5억원을 초과하는 금액의 42%)  │'),
#   Document(id='1d3b14c2-450c-4b35-a311-093c483d3f58', metadata={'source': './documents/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n│ 과세표준의 6개 구간 │\n|  세 율  |  과세표준 구간  |\n|----------|--------------------|\n│ 1,400만원 이하        │ 84만원 + (1,400만원을 초과하는 금액의 15%)  │\n│ 1,400만원 초과 ~ 5,000만원 이하 │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 5,000만원 초과 ~ 8,800만원 이하 │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 8,800만원 초과 ~ 1억5천만원 이하 │ 2,109만원 + (1억5천만원을 초과하는 금액의 38%)  │\n│ 1.5억원 초과 ~ 3억원 이하 │ 4,406만원 + (3억원을 초과하는 금액의 40%)  │\n│ 3억원 초과 │ 1억7,406만원 + (5억원을 초과하는 금액의 42%)  │'),
#   Document(id='f774ea50-cd2b-4b5e-a0ee-350463b76045', metadata={'source': './documents/income_tax.txt'}, page_content='5년 이하: 30만원 → 납입연수\n5년 초과 10년 이하: 150만원 + 50만원 × (납입연수 - 5년)\n10년 초과 20년 이하: 400만원 + 80만원 × (납입연수 - 10년)\n20년 초과: 1,200만원 + 120만원 × (납입연수 - 20년)\n\n② 직장근로자 초과관세환급금을 분배하여 지급받는 경우 세액의 계산 방법 등 필요한 사항은 대통령령으로 정한다. \n<대통령 2014. 12. 23.>\n<전문개정 2009. 12. 31.>\n제64조(부동산매매업자에 대한 세액 계산의 특례)\n1) 대통령령으로 정하는 부동산매매업(이하 “부동산매매업”이라 한다)을 영위하는 거주자가 이하 “부동산매매업자”라 한다)로서 종합소득세법에 제104조제1항제1호(본항을 포함한다) 및 제103조 또는 같은 조 제7항 각 호의 어느 하나에 해당하는 자산의 매매자익(이하 “주택등매매차익”이라 한다)이 있는 자의 종합소득 산출세액은 다음 각 호의 세액 중 많은 것으로 한다. \n<개정 2014. 12. 23., 2017. 12. 19., 2020. 12. 29.>\n1. 종합소득 산출세액\n\n다음 각 목에 따른 세액의 합계액\n  가. 주택등매매차익에 따른 세율을 적용하여 산출한 세액의 합계액\n  나. 종합소득세법 제55조에 따라 주택등매매차익에 대한 개별세액을 공제한 금액을 과세표준으로 하고 이에 제55조에 따른 세율을 적용하여 산출세액')],
#  'answer': '연봉 5천만 원에 대한 소득세는 624만 원입니다. 5천만 원 이하의 구간에 적용되는 세율에 따른 결과입니다.'}

# %%
initial_state = {'query': '역삼역 맛집을 추천해주세요'}
graph.invoke(initial_state)
# Out:
# context == [Document(id='337fab2b-249f-4632-a0d6-807503baee0b', metadata={'source': './documents/income_tax.txt'}, page_content='1. ‘세무처리’에 따른 세무조정을 통합한 세무서\n2. ‘세무조정’에 따른 세무조정방식으로 세무거래명부부록에 등록한 공인회계사\n3. ‘세무처리’에 따른 세무조정 또는 변호사 세무거래명부부록에 등록한 변호사\n[전문개정 2009. 12. 31.]\n[2021. 11. 23. 법률 제18521호에 의하여 2018. 4. 26. 헌법재판소에서 헌법불합치 결정에 의한 조치를 개정하였다.]\n제070조(종합소득과세표준 확정신고) ③ 해당 과세기간에 병립과세 주택매도소득, 제273조제1항제27조 및 제127조제1항제6호나목의 소득이 있는 경우에도 제126항에 따른 “종합소득 과세표준확정신고서”라 한다.\n➄ 종합소득과세표준확정신고를 할 때에는 “신고서”의 다음 각 호의 서류를 첨부하여 납세자에게 제출하여야 한다. 이 경우 제160조제3항에 따른 복식부기의무자가 제630호에 따른 세무를 제출하지 아니하는 경우에는 종합소득 과세표준확정신고로 하지 아니하는 것으로 본다.<개정 2010. 12. 27. 2012. 1. 1. 2014. 1. 1.>\n1. 인적증명, 연구보고서, 주택보조금부록, 특별소득증명, 자녀세액공제, 연금계좌세액공제 및 특별세액에 대한 내용을 증명하는 서류로서 대통령령으로 정하는 것\n2. 종합소득액의 계산이 기초한 총수입금액의 계산에 필요한 서류로서 대통령령으로 정하는 것\n3. 사업소득금액 제160조 및 제161조의2에 따른 비치·기록할 장부의 증명서류에 의하여 계산하지 아니하는 경우에는 기획재정부로 정하는 재무제표·손익계산서와 부속서류, 현황재무제표(現況財務表) 및 대통령령으로 정하는 바에 따라 작성한 조정계산서. 다만, 제160조제1항에 따라 기상(基商)을 한 사업자의 경우에는 기획재정부로 정하는 간편장부소득금액을 계산서\n6. 사업소득금액 제160조 및 제161조에 따라 비치·기록할 장부의 증명서류에 의하여 계산하지 아니하는 경우에는 기획재정부로 정하는 제출소득금액 계산서\n② 납세지 관할 세무서장이 제세특례신고서나 그 밖의 세무서 미비한 사항 또는 오류가 있을 때에는\n법 제처 50 국가법령정보센터\n소득세법\n⑥ 소득금액의 계산을 위한 세무조정을 정합히 하기 위하여 필요하다고 인정되어 제160조제3항에 따른 복식부기의무자로 대목적으로 정하는 사업자가 경우 세무정리제조에 따른 조건결산은 다음 각 호의 하나에 해당하는 경우 대목적범위로는 조정법인의 소속법인에서 자가 작성하여야 한다.<신설 2015. 12. 15, 2021. 11. 23.>\n1. ‘세무사법’에 따른 세무사등록에 통합된 세무사\n2. ‘세무사법’에 따른 세무사등록 또는 공인회계세 세무대리업무분류에 등록한 공인회계사\n3. ‘세무사법’에 따른 세무사등록 또는 변호사 세무대리업무분류에 등록한 변호사\n[전문개정 2009. 12. 31]\n[2021. 11. 23. 법률 제18521호에 의하여 2018. 4. 26. 헌법재판소에 헌법불합치 결정된 이 조를 개정함]\n[시행일: 2025. 1. 1. 가 격 70조]\n제70조의2(성실신고확인서 제출)'), Document(id='87ed8fd1-912d-4721-86ee-28f04707f8ff', metadata={'source': './documents/income_tax.txt'}, page_content='1. ‘세무처리’에 따른 세무조정을 통합한 세무서\n2. ‘세무조정’에 따른 세무조정방식으로 세무거래명부부록에 등록한 공인회계사\n3. ‘세무처리’에 따른 세무조정 또는 변호사 세무거래명부부록에 등록한 변호사\n[전문개정 2009. 12. 31.]\n[2021. 11. 23. 법률 제18521호에 의하여 2018. 4. 26. 헌법재판소에서 헌법불합치 결정에 의한 조치를 개정하였다.]\n제070조(종합소득과세표준 확정신고) ③ 해당 과세기간에 병립과세 주택매도소득, 제273조제1항제27조 및 제127조제1항제6호나목의 소득이 있는 경우에도 제126항에 따른 “종합소득 과세표준확정신고서”라 한다.\n➄ 종합소득과세표준확정신고를 할 때에는 “신고서”의 다음 각 호의 서류를 첨부하여 납세자에게 제출하여야 한다. 이 경우 제160조제3항에 따른 복식부기의무자가 제630호에 따른 세무를 제출하지 아니하는 경우에는 종합소득 과세표준확정신고로 하지 아니하는 것으로 본다.<개정 2010. 12. 27. 2012. 1. 1. 2014. 1. 1.>\n1. 인적증명, 연구보고서, 주택보조금부록, 특별소득증명, 자녀세액공제, 연금계좌세액공제 및 특별세액에 대한 내용을 증명하는 서류로서 대통령령으로 정하는 것\n2. 종합소득액의 계산이 기초한 총수입금액의 계산에 필요한 서류로서 대통령령으로 정하는 것\n3. 사업소득금액 제160조 및 제161조의2에 따른 비치·기록할 장부의 증명서류에 의하여 계산하지 아니하는 경우에는 기획재정부로 정하는 재무제표·손익계산서와 부속서류, 현황재무제표(現況財務表) 및 대통령령으로 정하는 바에 따라 작성한 조정계산서. 다만, 제160조제1항에 따라 기상(基商)을 한 사업자의 경우에는 기획재정부로 정하는 간편장부소득금액을 계산서\n6. 사업소득금액 제160조 및 제161조에 따라 비치·기록할 장부의 증명서류에 의하여 계산하지 아니하는 경우에는 기획재정부로 정하는 제출소득금액 계산서\n② 납세지 관할 세무서장이 제세특례신고서나 그 밖의 세무서 미비한 사항 또는 오류가 있을 때에는\n법 제처 50 국가법령정보센터\n소득세법\n⑥ 소득금액의 계산을 위한 세무조정을 정합히 하기 위하여 필요하다고 인정되어 제160조제3항에 따른 복식부기의무자로 대목적으로 정하는 사업자가 경우 세무정리제조에 따른 조건결산은 다음 각 호의 하나에 해당하는 경우 대목적범위로는 조정법인의 소속법인에서 자가 작성하여야 한다.<신설 2015. 12. 15, 2021. 11. 23.>\n1. ‘세무사법’에 따른 세무사등록에 통합된 세무사\n2. ‘세무사법’에 따른 세무사등록 또는 공인회계세 세무대리업무분류에 등록한 공인회계사\n3. ‘세무사법’에 따른 세무사등록 또는 변호사 세무대리업무분류에 등록한 변호사\n[전문개정 2009. 12. 31]\n[2021. 11. 23. 법률 제18521호에 의하여 2018. 4. 26. 헌법재판소에 헌법불합치 결정된 이 조를 개정함]\n[시행일: 2025. 1. 1. 가 격 70조]\n제70조의2(성실신고확인서 제출)'), Document(id='35089121-a1dd-4e1c-8b33-09f3d5b441e6', metadata={'source': './documents/income_tax.txt'}, page_content='담당세무서로서 담당공무원에게 지명이음으로는 보호를 위하는 바에 따라 담의 다음을 말하기는 것에 대한 해상금의 숙소는 본 해당하는 숙소는 달의 다음과 함께 말할 것이다. <개정 2020. 12. 29, 2021. 3. 16.>\n법제처 151\n국가법전정보센터')]
# doc relevance response: {'Score': 0, 'Explanation': 'The question is about recommending restaurants near Yeoksam Station, which is unrelated to income tax laws and regulations. The provided facts discuss details about tax filings, tax registrations, and procedures related to income tax, which do not contain any keywords or related semantic content to the topic of restaurants or locations near Yeoksam Station. Therefore, the score is 0, indicating the facts are completely unrelated to the question.'}
# rewrite question == "역삼역 근처 맛집 추천"
# web search results == {'query': '역삼역 근처 맛집 추천', 'follow_up_questions': None, 'answer': '신동궁 감자탕 역삼본점 is highly recommended near 역삼역, known for its 88-point rating and 4.3 average. Nearby, 빨강우산 부대찌개 offers hygienic, well-reviewed 부대찌개. 한판도 대학로점 is a popular 고기집 near 역삼역.', 'images': ['https://img.siksinhot.com/place/1676255404281522.jpg', 'https://mblogthumb-phinf.pstatic.net/MjAyNDEwMTVfMjgz/MDAxNzI4OTc1MzQ0MTA0.b7OoL30rv8ZXcoNCCwHGoNcww1BvlkoYor6ZNdO36pcg.yIE47UUiIP5lyQ6mHrsX_zMVEZGV6J5oZ5WPddvLdPwg.JPEG/%EC%A0%9C%EB%AA%A9%EC%9D%84_%EC%9E%85%EB%A0%A5%ED%95%B4%EC%A3%BC%EC%84%B8%EC%9A%94_-004_(2).jpg?type=w800', 'https://blog.kakaocdn.net/dna/bN5sdg/btsJ7pPTGIF/AAAAAAAAAAAAAAAAAAAAAKV5hZNlb8vkD7Uzj_qt2hcUu7hUtlkyskgRLgBbxfzo/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1780239599&allow_ip=&allow_referer=&signature=Hl6263lBM6f2DB3SsjO08YZd6Dg%3D', 'https://blog.jandi.com/ko/wp-content/uploads/sites/4/2015/04/image_revised_20.png', 'https://blog.kakaocdn.net/dna/u6NPN/btsJ8vhqSjV/AAAAAAAAAAAAAAAAAAAAAKAUV1eoU6Tpf6tV96zm4s_kvk0S-u5QGmlfC05Qqp-D/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1780239599&allow_ip=&allow_referer=&signature=mkRh4L2QnkKs0pKjhw%2FkON9ESlU%3D'], 'results': [{'url': 'https://hotel-iu.tistory.com/8573', 'title': '역삼역 점심 맛집 베스트 추천 top 10', 'content': "있으며 예약필수 입니다.  위치는 서울 강남구 논현로79길62에 있으며, 예약전화는 02-556-3677 입니다. 강남역 4번출구에서 7분, 역삼역 3번출구에서 6분 정도 도보로 손쉽게 찾으실 수 있으십니다. 2024년 2층 남녀 화장실 모두 호텔식으로 리모델링하였고, 에어컨 냉방, 난방설비도 2024년 최신형으로 완비하였습니다.  귀한 손님들을 모실때에는 꼭 강남맛집 고래불을 기억해주세요. 주중에는 발렛파킹 가능하며 주말에는 주차공간을 제공해드립니다. 발렛은 고래불의 직원이 직접하고 있으므로 더욱 주차하시기 편리하십니다.  네이버와 인스타그램, 유투브에서 고래불을 검색하면 관련자료들을 상세히 찾아보실 수 있으며, 음식사진과 메뉴들에 대한 설명도 자세히 보실수 있습니다.  (참조) 2024년 11월 25일부터 네이버 클파워챌린지의 핫플 클립 챌린지장소로 선정되었습니다.   | [...] 완벽한 선택이 됩니다.  3. 위생 걱정 없이 즐기는 부대찌개  음식은 맛 뿐만 아니라 안전해야 합니다. 빨강우산부대찌개는 식약처 인증 위생등급 '매우 우수'를 받은 식당입니다. 철저한 식재료 관리와 청결한 조리 환경을 유지하며, 언제나 안심하고 즐길 수 있는 공간을 만듭니다.  \\ 주차 안내 성지하이츠1 오피스텔 주차장 이용 가능 주차료 : 10분당 1,200원(변동 가능) 주차비 지원 없음(대중교통 이용 추천) '모두의 주차장'앱을 통해 근처 저렴한 유료주차장 검색 가능  선릉역 주변 식당을 찾는다면, 빨강우산 부대찌개를 꼭 방문해 보세요! 선릉 직장인들이 인정하는 부대찌개집으로, 푸짐한 한 끼를 책임지는 곳입니다. 가성비 좋은 식사를 원한다면, 그리고 다양한 재료가 무한리필되는 부대찌개를 즐기고 싶다면 지금 방문해 보세요.  ''빨강우산''의 따뜻하고 포근한 품 안에서 시그니처 부대찌개 한 숟가락에 국물의 따스함과 과거와 현대의 맛의 조화를 느껴보세요~ 감사합니다^^  Feel the warmth of the soup and the harmony of the past and modern tastes with a spoonful of signature budaejjigae in the warm and cozy arms of 'Red Umbrella'~ Thank you ^^ | [...] 이용하시면서 가성비있게 행복한 추억을 만드시길 바랍니다  한판도 대학로점 Meets Lounge 고기와 라운지가 만나다, 대학로 고기집 한판도입니다. 50명 이하 단체 및 대관 가능 마이크 보유  혜화역 4번출구에서 도보 2분거리!! 서울대학병원 옆에 있는 대학로 CGV 대명길에 있습니다!! 가성비맛집으로 대학로삼겹살과 고기전복삼합을 즐겨보세요 |", 'score': 0.9999335, 'raw_content': '# [초코초코 해피라이프](https://hotel-iu.tistory.com/ "초코초코 해피라이프")\n\n추천 TOP 10\n\n## 역삼역 점심 맛집 베스트 추천 top 10\n\n초코초코 코니코니 2025. 2. 27. 20:24\n\n반응형\n\n#### **역삼역 점심 맛집 베스트 추천 top 10**\n\n---\n\n역삼역 점심 맛집 베스트 추천 top 10곳을 소개합니다.\n\n---\n\n|  |\n| --- |\n| **1: 아침점심저녁 강남점** |\n|  |\n| 상호명: 아침점심저녁 강남점  주소: 서울특별시 강남구 역삼동 706-17 지하1층 B102호  전화번호: 미입력  관련 키워드: [\'제육계란이불덮밥\', \'순살닭도리탕\', \'아구도리탕\', \'불고기덮밥\', \'고등어덮밥\']  관련 태그: 미입력  영업시간: 미입력 |\n| 소개글: 몽글몽글한 계란과 어울리는 재료들의 덮밥과 집밥 생각나는 따뜻한 찌개요리들 배달과 포장을 전문으로 하고있습니다!! |\n| **<https://map.naver.com/p/entry/place/1249578375>** 아침점심저녁 강남점 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **2: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문** |\n|  |\n| 상호명: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문  주소: 서울특별시 강남구 역삼동 702-13 성지하이츠1 오피스텔 지하1층 107호  전화번호: 미입력  관련 키워드: [\'선릉역부대찌개\', \'강남점심식당\', \'선릉역점심\', \'역삼역직장인저녁\', \'선릉역밥집\']  관련 태그: [\'데이트하기 좋은\', \'젊고 캐쥬얼한\', \'모임하기 좋은\']  영업시간: 평일 11:00~15:00 | 평일 17:00~20:00 |\n| 소개글: 선릉 직장인의 든든한 밥집 빨강우산부대찌개를 소개합니다.  2017년 개업 이래, 빨강우산부대찌개는 선릉역 근처에서 줄서는 식당으로 서서히 입소문을 탄 가게가 되었습니다. 단일 메뉴인 부대찌개 하나만 판매하며 이곳은 맛과 가성비 모두를 만족시키며 많은 이들의 사랑을 받고 있습니다.  1. 9000원의 행복! 밥,라면,느타리버섯,납작당면까지 무한리필!  한 끼를 먹어도 제대로 먹어야 합니다. 선릉 직장인들의 점심,저녁 고민을 덜어 주는 빨강우산 부대찌개에서는 밥,라면,느타리버섯,납작당면을 무한리필로 제공합니다. 한번 먹고 아쉽다면, 마음껏 더 드세요. 속이 든든해야 일도 잘 풀리는 법입니다.  이곳은 행정안전부와 강남구에서 선정한 착한가격 업소입니다. 비싼 강남 한복판에서도 9,000원이면 배부르게 먹을수 있는 곳, 주머니 사정이 ...
# {'query': '"역삼역 근처 맛집 추천"',
#  'context': {'query': '역삼역 근처 맛집 추천',
#   'follow_up_questions': None,
#   'answer': '신동궁 감자탕 역삼본점 is highly recommended near 역삼역, known for its 88-point rating and 4.3 average. Nearby, 빨강우산 부대찌개 offers hygienic, well-reviewed 부대찌개. 한판도 대학로점 is a popular 고기집 near 역삼역.',
#   'images': ['https://img.siksinhot.com/place/1676255404281522.jpg',
#    'https://mblogthumb-phinf.pstatic.net/MjAyNDEwMTVfMjgz/MDAxNzI4OTc1MzQ0MTA0.b7OoL30rv8ZXcoNCCwHGoNcww1BvlkoYor6ZNdO36pcg.yIE47UUiIP5lyQ6mHrsX_zMVEZGV6J5oZ5WPddvLdPwg.JPEG/%EC%A0%9C%EB%AA%A9%EC%9D%84_%EC%9E%85%EB%A0%A5%ED%95%B4%EC%A3%BC%EC%84%B8%EC%9A%94_-004_(2).jpg?type=w800',
#    'https://blog.kakaocdn.net/dna/bN5sdg/btsJ7pPTGIF/AAAAAAAAAAAAAAAAAAAAAKV5hZNlb8vkD7Uzj_qt2hcUu7hUtlkyskgRLgBbxfzo/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1780239599&allow_ip=&allow_referer=&signature=Hl6263lBM6f2DB3SsjO08YZd6Dg%3D',
#    'https://blog.jandi.com/ko/wp-content/uploads/sites/4/2015/04/image_revised_20.png',
#    'https://blog.kakaocdn.net/dna/u6NPN/btsJ8vhqSjV/AAAAAAAAAAAAAAAAAAAAAKAUV1eoU6Tpf6tV96zm4s_kvk0S-u5QGmlfC05Qqp-D/img.jpg?credential=yqXZFxpELC7KVnFOS48ylbz2pIh7yKj8&expires=1780239599&allow_ip=&allow_referer=&signature=mkRh4L2QnkKs0pKjhw%2FkON9ESlU%3D'],
#   'results': [{'url': 'https://hotel-iu.tistory.com/8573',
#     'title': '역삼역 점심 맛집 베스트 추천 top 10',
#     'content': "있으며 예약필수 입니다.  위치는 서울 강남구 논현로79길62에 있으며, 예약전화는 02-556-3677 입니다. 강남역 4번출구에서 7분, 역삼역 3번출구에서 6분 정도 도보로 손쉽게 찾으실 수 있으십니다. 2024년 2층 남녀 화장실 모두 호텔식으로 리모델링하였고, 에어컨 냉방, 난방설비도 2024년 최신형으로 완비하였습니다.  귀한 손님들을 모실때에는 꼭 강남맛집 고래불을 기억해주세요. 주중에는 발렛파킹 가능하며 주말에는 주차공간을 제공해드립니다. 발렛은 고래불의 직원이 직접하고 있으므로 더욱 주차하시기 편리하십니다.  네이버와 인스타그램, 유투브에서 고래불을 검색하면 관련자료들을 상세히 찾아보실 수 있으며, 음식사진과 메뉴들에 대한 설명도 자세히 보실수 있습니다.  (참조) 2024년 11월 25일부터 네이버 클파워챌린지의 핫플 클립 챌린지장소로 선정되었습니다.   | [...] 완벽한 선택이 됩니다.  3. 위생 걱정 없이 즐기는 부대찌개  음식은 맛 뿐만 아니라 안전해야 합니다. 빨강우산부대찌개는 식약처 인증 위생등급 '매우 우수'를 받은 식당입니다. 철저한 식재료 관리와 청결한 조리 환경을 유지하며, 언제나 안심하고 즐길 수 있는 공간을 만듭니다.  \\ 주차 안내 성지하이츠1 오피스텔 주차장 이용 가능 주차료 : 10분당 1,200원(변동 가능) 주차비 지원 없음(대중교통 이용 추천) '모두의 주차장'앱을 통해 근처 저렴한 유료주차장 검색 가능  선릉역 주변 식당을 찾는다면, 빨강우산 부대찌개를 꼭 방문해 보세요! 선릉 직장인들이 인정하는 부대찌개집으로, 푸짐한 한 끼를 책임지는 곳입니다. 가성비 좋은 식사를 원한다면, 그리고 다양한 재료가 무한리필되는 부대찌개를 즐기고 싶다면 지금 방문해 보세요.  ''빨강우산''의 따뜻하고 포근한 품 안에서 시그니처 부대찌개 한 숟가락에 국물의 따스함과 과거와 현대의 맛의 조화를 느껴보세요~ 감사합니다^^  Feel the warmth of the soup and the harmony of the past and modern tastes with a spoonful of signature budaejjigae in the warm and cozy arms of 'Red Umbrella'~ Thank you ^^ | [...] 이용하시면서 가성비있게 행복한 추억을 만드시길 바랍니다  한판도 대학로점 Meets Lounge 고기와 라운지가 만나다, 대학로 고기집 한판도입니다. 50명 이하 단체 및 대관 가능 마이크 보유  혜화역 4번출구에서 도보 2분거리!! 서울대학병원 옆에 있는 대학로 CGV 대명길에 있습니다!! 가성비맛집으로 대학로삼겹살과 고기전복삼합을 즐겨보세요 |",
#     'score': 0.9999335,
#     'raw_content': '# [초코초코 해피라이프](https://hotel-iu.tistory.com/ "초코초코 해피라이프")\n\n추천 TOP 10\n\n## 역삼역 점심 맛집 베스트 추천 top 10\n\n초코초코 코니코니 2025. 2. 27. 20:24\n\n반응형\n\n#### **역삼역 점심 맛집 베스트 추천 top 10**\n\n---\n\n역삼역 점심 맛집 베스트 추천 top 10곳을 소개합니다.\n\n---\n\n|  |\n| --- |\n| **1: 아침점심저녁 강남점** |\n|  |\n| 상호명: 아침점심저녁 강남점  주소: 서울특별시 강남구 역삼동 706-17 지하1층 B102호  전화번호: 미입력  관련 키워드: [\'제육계란이불덮밥\', \'순살닭도리탕\', \'아구도리탕\', \'불고기덮밥\', \'고등어덮밥\']  관련 태그: 미입력  영업시간: 미입력 |\n| 소개글: 몽글몽글한 계란과 어울리는 재료들의 덮밥과 집밥 생각나는 따뜻한 찌개요리들 배달과 포장을 전문으로 하고있습니다!! |\n| **<https://map.naver.com/p/entry/place/1249578375>** 아침점심저녁 강남점 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **2: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문** |\n|  |\n| 상호명: 빨강우산 부대찌개 선릉역 본점 점심저녁 전문  주소: 서울특별시 강남구 역삼동 702-13 성지하이츠1 오피스텔 지하1층 107호  전화번호: 미입력  관련 키워드: [\'선릉역부대찌개\', \'강남점심식당\', \'선릉역점심\', \'역삼역직장인저녁\', \'선릉역밥집\']  관련 태그: [\'데이트하기 좋은\', \'젊고 캐쥬얼한\', \'모임하기 좋은\']  영업시간: 평일 11:00~15:00 | 평일 17:00~20:00 |\n| 소개글: 선릉 직장인의 든든한 밥집 빨강우산부대찌개를 소개합니다.  2017년 개업 이래, 빨강우산부대찌개는 선릉역 근처에서 줄서는 식당으로 서서히 입소문을 탄 가게가 되었습니다. 단일 메뉴인 부대찌개 하나만 판매하며 이곳은 맛과 가성비 모두를 만족시키며 많은 이들의 사랑을 받고 있습니다.  1. 9000원의 행복! 밥,라면,느타리버섯,납작당면까지 무한리필!  한 끼를 먹어도 제대로 먹어야 합니다. 선릉 직장인들의 점심,저녁 고민을 덜어 주는 빨강우산 부대찌개에서는 밥,라면,느타리버섯,납작당면을 무한리필로 제공합니다. 한번 먹고 아쉽다면, 마음껏 더 드세요. 속이 든든해야 일도 잘 풀리는 법입니다.  이곳은 행정안전부와 강남구에서 선정한 착한가격 업소입니다. 비싼 강남 한복판에서도 9,000원이면 배부르게 먹을수 있는 곳, 주머니 사정이 팍팍해도 부담없이 따뜻한 한 끼를 즐길수 있는 곳. 그래서 많은 사람들이 찾고, 한 번 온 손님들은 단골이 됩니다.  2. 15년 동안 오직 부대찌개만 연구한 주인장의 정성  빨강우산부대찌개는 15년간 오직 부대찌개만을 연구한 주인장의 손길이 담긴 곳입니다. 한우 사골로 직접 끓이는 육수, 비법 양념이 만나 감칠맛을 냅니다.  이 곳의 부대찌개는 존슨빌 소세지와 후랑크소세지, 스팸, 신선한 채소, 그리고 쫄깃한 라면사리까지 어우러진 깊고 푸짐한 맛과 청양고춧가루가 첨가된 양념의 개운한 맛 덕분에, 해장용으로도, 점심식사와 단체 모임 회식, 가족 식사로도 완벽한 선택이 됩니다.  3. 위생 걱정 없이 즐기는 부대찌개  음식은 맛 뿐만 아니라 안전해야 합니다. 빨강우산부대찌개는 식약처 인증 위생등급 \'매우 우수\'를 받은 식당입니다. 철저한 식재료 관리와 청결한 조리 환경을 유지하며, 언제나 안심하고 즐길 수 있는 공간을 만듭니다.  \\* 주차 안내 성지하이츠1 오피스텔 주차장 이용 가능 주차료 : 10분당 1,200원(변동 가능) 주차비 지원 없음(대중교통 이용 추천) \'모두의 주차장\'앱을 통해 근처 저렴한 유료주차장 검색 가능  선릉역 주변 식당을 찾는다면, 빨강우산 부대찌개를 꼭 방문해 보세요! 선릉 직장인들이 인정하는 부대찌개집으로, 푸짐한 한 끼를 책임지는 곳입니다. 가성비 좋은 식사를 원한다면, 그리고 다양한 재료가 무한리필되는 부대찌개를 즐기고 싶다면 지금 방문해 보세요.  \'\'빨강우산\'\'의 따뜻하고 포근한 품 안에서 시그니처 부대찌개 한 숟가락에 국물의 따스함과 과거와 현대의 맛의 조화를 느껴보세요~ 감사합니다^^  Feel the warmth of the soup and the harmony of the past and modern tastes with a spoonful of signature budaejjigae in the warm and cozy arms of \'Red Umbrella\'~ Thank you ^^ |\n| **<https://map.naver.com/p/entry/place/1559151290>** 빨강우산 부대찌개 선릉역 본점 점심저녁 전문 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **3: 동화고옥 강남 N타워점** |\n|  |\n| 상호명: 동화고옥 강남 N타워점  주소: 서울특별시 강남구 역삼동 648-9 B2 동화고옥 강남 N타워점  전화번호: 미입력  관련 키워드: [\'강남룸식당\', \'강남점심\', \'강남상견례\', \'강남코스요리\', \'강남한정식\']  관련 태그: 미입력  영업시간: 미입력 |\n| 소개글: Bloom in the Palace, 함께 모여 꽃이 피어나는 집 동화고옥 강남 N타워점에서 인사드립니다.  저희 동화고옥은 고객님들의 많은 사랑을 받아 강남 N타워점에 새롭게 재단장하여 오픈하였습니다. 강남 한정식, 강남역 룸식당 을 찾으시는 고객님께 추천드리며,  강남 N타워 맛집 동화고옥은 우리 음식 문화의 정수라 할 수 있는 \'궁중 음식\'을 현대적으로 전승해 아름다운 우리 식문화를 재현하여 고급스러운 분위기와 맛을 선보이는 매장으로 강남역 상견례 장소로도 추천드립니다.  귀한 성찬, 좋은 벗과 함께하는 정성이 가득한 시간을 뜰 속에서 소중한 가족, 연인과 함께 향기로운 기운을 맞이하세요! |\n| **<https://map.naver.com/p/entry/place/1825366493>** 동화고옥 강남 N타워점 바로가기▲ |\n\n---\n\n|  |\n| --- |\n| **4: 온심옥 역삼본점** |\n|  |\n| 상호명: 온심옥 역삼본점  주소: 서울특별시 강남구 역삼동 640-23 1층 온심옥 역삼본점  전화번호: 미입력  관련 키워드: [\'회식\', \'직장인\', \'가족외식장소\', \'점심\', \'서울한식\']  관련 태그: [\'데이트하기 좋은\', \'단체회식\', \'젊고 캐쥬얼한\']  영업시간: 매일 11:00~21:30 마지막 주문 21:00 | 일요일 휴무 |\n| 소개글: 안녕하세요. 따듯한 마음을 잇는 집 온심옥 입니다..  저희 갈비탕은 필터 3개로 걸러낸 맑은 물만을 사용하여 20시간 이상 푹 끓여 내어, 속이 탁! 풀리는 진한 국물을 선사합니다.  갈비탕은 임금님께서 드시던 최고의 보약 음식으로 코로나로 병원을 자주 다니시는 분들 70세 이상 어르신들도 기력 회복에 큰 도움이 되는 보약입니다. (어르신들에게는 1000원 할인 혜택)  갈비는 최상의 등급 초이스 척갈비를 쓰고 있으며 매우 부드럽고 쫄깃한 식감을!! 속이편한 갈비탕에는 속이 편하게 만들어주는 효과가 있는 우엉을 넣어 육수를 만들어내는 갈비탕은 온심옥 역삼본점에서만 드실 수 있는 갈비탕입니다.  갈비살을 온심옥에만 있는 특제 소스인 초록다데기와 육장소스를 찍어드시거나 탕에 풀어 드시면 어디에서도 드실 수 없는 갈비탕의 새로운 맛을 느끼게 되실 겁니다.  온심옥의 베스트 메뉴는 갈비탕 외에 매운 갈비찜은 맛~있게 매운 양념이 화요+토닉과 최고의 조합을 자랑한답니다! 식사 후 버터와 밥을 비벼 드시거나 깍두기 볶음밥으로 마무리하시면 최고의 식사를 하실 수 있습니다.  한우곱창전골은 일주일 동안 열심히 일하신 분들 동료들과 금요일 저녁 소주 한잔 생각나 실 때 \'온심옥\'에서 한우곱창전골 드시면서 서로 그동안 고민했던 이야기들이 자연스럽게 대화할 수 있는 ...
#     'images': ['https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdna%2FbfW1F8%2FbtsMxFvCQRL%2FAAAAAAAAAAAAAAAAAAAAAOd2L2NS6cAixMoNTTD_1IxTCngl0UzbaDkecM-KI5P6%2Fimg.png%3Fcredential%3DyqXZFxpELC7KVnFOS48ylbz2pIh7yKj8%26expires%3D1780239599%26allow_ip%3D%26allow_referer%3D%26signature%3DyFr58ptDJsU4ZkKJJc%252FwIEFjNsA%253D',
#      'https://tistory1.daumcdn.net/tistory/4349053/attach/3d0219e7e1fd4caf9df6433a3bc3c789']},
#    {'url': 'https://m.blog.naver.com/je3355je/223613149295',
#     'title': '역삼역 맛집 리스트 2년차 직장인 또간집 TOP 30 - 네이버 블로그',
#     'content': 'No.종류상호명자주 먹은 메뉴주소거리\n1 한식 뚝배기양평해장국 역삼직영점 뼈해장국 서울 강남구 테헤란로27길 36 1층 뚝배기양평해장국 역삼역 8번 출구에서 372m\n2 일식 스노우폭스 역삼 GFC점 필라델피아롤, 와규스테이크스시 서울 강남구 테헤란로 152 강남파이낸스센터 지하2층 역삼역 2번 출구에서 27m\n3 중식 명정루 간짜장, 짬뽕 서울 강남구 논현로 94길 19 1층 역삼역 7번 출구에서 270m\n4 한식 본죽&비빔밥cafe 역삼역점 삼계죽 서울 강남구 봉은사로30길 78 2층 역삼역 7번 출구에서 212m\n5 한식 모퉁이식당 고등어김치찜 서울 강남구 테헤란로14길 33 2층 역삼역 3번 출구에서 510m\n6 한식 오성식당 역삼 쌈돼지김치찌개 서울 강남구 테헤란로33길 13 2층 역삼역 8번 출구에서 335m\n7 샐러드 뷰티풀샐러드&도시락 목살샐러드 서울 강남구 테헤란로33길 26 1층 역삼역 8번 출구에서 428m\n8 햄버거 바스버거 역삼직영점 바스버거 서울 강남구 테헤란로26길 10 성보빌딩 지하1층 역삼역 3번 출구에서 89m\n9 한식술집 카즈야 김치우동 서울 강남구 테헤란로27길 8-4 늘봄빌딩 1층 역삼역 8번 출구에서 206m\n10 분식 민들레떡볶이 우삼겹떡볶이+튀김세트 서울 강남구 논현로94길 11 2층 역삼역 7번 출구에서 217m\n11 일식 호타루 소유라멘, 규동 서울 강남구 테헤란로25길 9-10 역삼역 4번 출구에서 147m\n12 햄버거 스매쉬치즈버거 스매쉬새우버거 서울 강남구 강남대로94길 89 역삼역 4번 출구에서 142m [...] 24 카페 지오바네커피 아인슈페너 서울 강남구 논현로98길 5 1층 101호 역삼역 7번 출구에서 316m\n25 카페 루스터 아몬드 아인슈페너 서울 강남구 논현로86길 22 1층 역삼역 1번 출구에서 319m\n26 카페 커피사피엔스 역삼 푸르지오점 에이드,수박주스 서울 강남구 논현로85길 52 푸르지오시티 101호 역삼역 3번 출구에서 326m\n28 이자카야 아리네술상 생연어덮밥,연어랑육회랑 서울 강남구 논현로94길 11 지하 1층 역삼역 7번 출구에서 217m\n29 이자카야 더 간사이 간사이오뎅 서울 강남구 논현로85길 35 세하빌딩 1층 역삼역 3번 출구에서 254m\n30 한식주점 이백 육회,골뱅이무침 서울 강남구 언주로85길 14 엠코스퀘어720 역삼역 1번 출구에서 510m [...] 12 햄버거 스매쉬치즈버거 스매쉬새우버거 서울 강남구 강남대로94길 89 역삼역 4번 출구에서 142m\n13 한식 내림손삼계탕 역삼점 일반 반계탕 서울 강남구 논현로 428 역삼역 1번 출구에서 241m\n14 베트남식 분짜라붐 역삼점 하노이 쌀국수 서울 강남구 테헤란로25길 13 1-2층 역삼역 4번 출구에서 140m\n15 한식 돈우정 김치찌개, 육회비빔밥 서울 강남구 봉은사로30길 73 1층 역삼역 7번 출구에서 255m\n16 한식 이도곰탕 본점 한우곰탕 서울 강남구 논현로94길 29-5 역삼역 8번 출구에서 359m\n17 한식 진대감 역삼점 한우차돌짬뽕라면밥상 서울 강남구 봉은사로30길 75 1층 역삼역 7번 출구에서 228m\n18 이탈리아식 지아니스나폴리 역삼 본점 점심 피자 서울 강남구 논현로94길 15 B1층 역삼역 7번 출구에서 267m\n19 카페 타우너스 에스프레소 바 역삼점 데미타세 아포가토 서울 강남구 테헤란로28길 41 타우너스 1층 역삼역 1번 출구에서 446m\n20 카페 스타벅스 GS타워점 돌체라떼 서울 강남구 논현로 508-2 역삼역 7번 출구에서 182m\n21 카페 뮬리 아메리카노 서울 강남구 논현로93길 6 1층 역삼역 6번 출구에서 160m\n22 카페 터프커피 자몽허니블랙티 서울 강남구 테헤란로25길 19 1층 역삼역 6번 출구에서 187m\n23 카페 아티제 역삼역점 아메리카노 서울 강남구 테헤란로 203 서울인터내셔널타워 역삼역 8번 출구에서 122m\n24 카페 지오바네커피 아인슈페너 서울 강남구 논현로98길 5 1층 101호 역삼역 7번 출구에서 316m',
#     'score': 0.9999069,
#     'raw_content': '# 역삼역 맛집 리스트 2년차 직장인 또간집 TOP 30 : 네이버 블로그\n\n[로그인이 필요합니다.](https://m.blog.naver.com/je3355je/223613149295#)\n*   [내소식](https://m.blog.naver.com/News.naver)\n*   [이웃목록](https://m.blog.naver.com/GoMyBuddyList.naver)\n*   [통계](https://m.blog.naver.com/BlogStat.naver)\n*   [클립만들기](https://m.blog.naver.com/je3355je/223613149295)\n*   [글쓰기](https://m.blog.naver.com/je3355je/223613149295)\n\n[_My Menu 닫기_](https://m.blog.naver.com/je3355je/223613149295)\n\n[내 체크인](https://m.blog.naver.com/CheckIn.naver)[최근 본 글](https://m.blog.naver.com/ReadHistoryList.naver)[내 동영상](https://m.blog.naver.com/MyVideo.naver)[내 클립](https://m.blog.naver.com/ClipList.naver)\n\n* * *\n\n[내 상품 관리 NEW](https://m.blog.naver.com/je3355je/223613149295)[마켓 플레이스 NEW](https://m.blog.naver.com/MarketPlace.naver)[장바구니](https://m.blog.naver.com/Cart.naver)[마켓 구매내역](https://new-m.pay.naver.com/historybenefit/paymenthistory)\n\n* * *\n\n[블로그팀 공식블로그 NEW](https://m.blog.naver.com/PostList.naver?blogId=blogpeople)[이달의 블로그](https://m.blog.naver.com/PopularBlog.naver)[공식 블로그](https://m.blog.naver.com/OfficialBlog.naver)[블로그 앱](https://m.blog.naver.com/je3355je/223613149295)\n\n* * *\n\n[로그인](https://m.blog.naver.com/je3355je/223613149295)[PC버전으로 보기](https://blog.naver.com/je3355je/223613149295?viewType=pc)[블로그 고객센터](https://help.naver.com/alias/blog/etc/bl_code_01.naver)\n\n[![Image 1: 섬네일](https://m.blog.naver.com/je3355je/223613149295)](https://m.blog.naver.com/je3355je/223613149295)\n\n[ⓒ NAVER Corp.](https://www.navercorp.com/)\n\n[본문 바로가기](https://m.blog.naver.com/je3355je/223613149295#ct)\n\n# [블로그](https://m.blog.naver.com/Recommendation.naver)\n\n## [카테고리 이동](https://m.blog.naver.com/je3355je/223613149295#)[식도락 여행일기](https://m.blog.naver.com/PostList.naver?blogId=je3355je)\n\n[검색](https://m.blog.naver.com/PostSearchList.naver?blogId=je3355je)MY메뉴 열기\n\n[맛집 모음](https://m.blog.naver.com/PostList.naver?blogId=je3355je&categoryNo=52&logCode=0&categoryName=%EB%A7%9B%EC%A7%91+%EB%AA%A8%EC%9D%8C#postlist_block)\n\n역삼역 맛집 리스트 2년차 직장인 또간집 TOP 30\n\n[![Image 2: 프로필](https://blogpfthumb-phinf.pstatic.net/MjAyNjA0MTZfMzAw/MDAxNzc2MzQ2MzU5NDA1.70D7Nj6oImHzuA4FkaQHrut-ipwm8-tIoO2N9EQMhP4g.-PxUc9Jk8o1TuDMo82_iAmHwqY8c13hn9GUDq2bwzdEg.JPEG/profileImage.jpg?type=s1)](https://m.blog.naver.com/PostList.naver?blogId=je3355je)\n\n[**오션**](https://m.blog.naver.com/PostList.naver?blogId=je3355je)\n\n2024. 10. 10. 8:10\n\n[이웃추가](https://m.blog.naver.com/je3355je/223613149295#)\n\n본문 기타 기능\n\n*   **본문 폰트 크기 조정**본문 폰트 크기 작게 보기 본문 폰트 크기 크게 보기 가\n*   [공유하기](https://m.blog.naver.com/je3355je/223613149295#)\n*   [URL복사](https://m.blog.naver.com/je3355je/223613149295#)\n*   [신고하기](https://m.blog.naver.com/je3355je/223613149295#)\n\n[위치 카즈야](https://m.place.naver.com/place/86771976)\n\n[![Image 3](https://mblogthumb-phinf.pstatic.net/MjAyNDEwMTVfMTQw/MDAxNzI4OTczMTMyMjI2.2Qc8yvXzL_RzLVWTQcHzU8woU1qkuxzihE05l_ujm7Yg.Q9GhiECR9W_XvSiKO0izkpf_m_Oi9IjqG1zMnLBYlJYg.JPEG/003.jpg?type=w800)](https://m.blog.naver.com/je3355je/223613149295)\n\n\u200b\n\n\u200b\n\n방문을 환영합니다~\n\n[![Image 4](https://storep-phinf.pstatic.net/ogq_5ebebeedf0c9a/original_16.png?type=p100_100)](https://m.blog.naver.com/je3355je/223613149295#)\n\n저는 2년동안 역삼역 근처 여러 맛집에서\n\n점심&저녁을 먹었습니다.\n\n\u200b\n\n그 중 맛있었던 곳만 모아둔\n\n**맛집/카페/술집 리스트 무료 배포합니다!**\n\n**오션 또간집 레츠기릿~~!**\n\n[![Image 5](https://storep-phinf.pstatic.net/ogq_5ebebeedf0c9a/original_1.png?type=p100_100)](https://m.blog.naver.com/je3355je/223613149295#)\n\n[![Image 6](https://mblogthumb-phinf.pstatic.net/MjAyNDA1MDVfMTky/MDAxNzE0OTA0NzA0MjE4.nQnfUlw_KCd2IYcsxW2-WnTKtnN4y0gH8d3s0lBOBlQg.PfbtKtfHUVm1VxHjg9q9kMJD18qURd2HbifbVeCsoMQg.JPEG/IMG%EF%BC%BF4859.JPG?type=w800)](https://m.blog.naver.com/je3355je/223613149295)\n\n\u200b\n\n역삼역 근처에서 식사를 자주 하신다면\n\n저장하시고 뭐먹을지 고민될 때마다 보세요^^\n\n특히 친절하시고 맛있는 곳은 하단에 지도 첨부했어요.\n\n\u200b\n\n**No.****종류****상호명****자주 먹은 메뉴****주소****거리**\n1 한식 뚝배기양평해장국 역삼직영점 뼈해장국 서울 강남구 테헤란로27길 36 1층 뚝배기양평해장국 역삼역 8번 출구에서 372m\n2 일식 스노우폭스 역삼 GFC점 필라델피 ...
#     'images': []},
#    {'url': 'https://www.teamblind.com/kr/post/%EC%97%AD%EC%82%BC%EC%97%AD-%ED%94%84%EB%A1%9C%EC%B6%9C%EA%B7%BC%EB%9F%AC%EC%9D%98-%EC%A0%90%EC%8B%AC-%EC%B6%94%EC%B2%9C-%EB%A7%9B%EC%A7%91-%ED%92%80%EC%96%B4%EB%B3%B4%EC%95%84%EC%9A%A9%E2%98%BA%EF%B8%8F-BVD3hD3r',
#     'title': '블라인드 | 블라블라: 역삼역 프로출근러의 점심 추천 맛집 풀어보아용☺️',
#     'content': '지아니스나폴리) 도저히 뺄 수 없는 양식 맛집!  \n  \n\\\\\\중식\\\\\\  \n  \n차이향) 세트메뉴 구성 잘 되어 있고, 자장면 짬뽕 괜찮고 마파두부도 괜찮아!  \n  \n양궈푸 마라탕) 마라탕 초보자를 위한 사골 육수 베이스의 마라탕집! 하이디라오 좋아하면 이건 좀 다른 류의 마라탕인데 하겠지만, 또 역삼에 이만한 마라탕 집이 없다는?! ->여기 주방장님 바뀜 이젠 안감…맛없어..  \n  \n명정루) 중화국밥 맛집이라능! 불맛 좋아하는 짬뽕러버들을 위한 집이지!  \n  \n안ㅅㅂ) 더이상 맛집이 아니라는..  \n  \n웨이웨이) 우삼겹 탄탄면 꼭 먹어봐! 튀김류는 그냥 그래 ㅎㅎ 나는 추천하진 않아ㅋ  \n  \n차알) 가격대는 앞서 말한 집들에 비해 높지만, 딱 정말 미국서 먹는 중국 요리 맛이 이거구나 하는 입에 착착 감기는 맛임.',
#     'score': 0.9998118,
#     'raw_content': '# [블라인드 - 직장인 기업 연봉, 이직 커리어 *Blind LOGO* *Blind BI*](/kr/)\n\n![금주의 특가](https://static.teamblind.com/img/www_kr/img-coupang-week-light.svg)\n\n# 검색\n\n# [채널](/kr/topics/%EC%A0%84%EC%B2%B4) [블라블라](/kr/topics/%EB%B8%94%EB%9D%BC%EB%B8%94%EB%9D%BC) · 팔로우\n\n## 역삼역 프로출근러의 점심 추천 맛집 풀어보아용☺️\n\n월요일인데 회사 일 말고 뭔가 나만의 하루를 보내기 위한 역삼 점심 맛집들 풀어보려구! 쓰다보니 1시간 가버렸네! 역삼 출근자들에게 도움 되길🙆🏻\u200d♀️  \n  \n댓글로 새로운 맛집 추천 받아♥️ 미리 고마워~  \n  \n\\*\\*\\*한식\\*\\*\\*  \n  \n서울집) 손수 만드신 만두와 칼국수 메뉴들이고, 국물이 깔끔하다. 날 추워지면 생각나.  \n  \n복돈이 가마솥 순대국) 이 집 순대국이 역삼역 센터필드 방향 중 최고임!  \n  \n우리집) 뚝배기 닭볶음탕, 오징어볶음 자극적인 양념 맛이지만 양념 맛이 장난이 아닌 맛집.  \n  \n라비옥) 구운 갈비 먹고 싶은 날엔 무조건 라비옥! 정식도 있고 갈비 덮밥도 있고.  \n  \n갈비다움) 갈비탕을 안좋아하는데… 이 집은 인정이에요! 가격은 좀 있지만, 고기양도 좀 있고 국물이 매우 깔꼼~  \n  \n네모오징어) 점심에만 시킬 수 있는 오징어 볶음류들 맛있고 마지막에 밥 넣고 비벼서 철판볶음판 처럼 해먹으면 꿀맛 !  \n  \n제주강국수) 일단 고기국수랑 국밥 인정 메달 드림 ㅎ  \n  \n민이한상) 고급지게 한 상 차림으로 솥밥 껴서 먹고 싶은 날엔 여기지  \n  \n속초코다리냉면) 꼭 만두랑 세트로 먹어주라 냉면. 킹인정 못하면 찾아와.  \n  \n소담길) 닭개장 먹어 꼭 먹어. 진짜 과식하게 하는 맛집 중 하나.  \n  \n방이옥) 제육볶음 맛있는데 파 냄새가 오래갈거야 ㅋㅋ 하지만 맛있어!  \n  \n전봇대) 콩국수부터 일반 국수 그리고 해물칼국수 존맛탱임  \n  \n심가네 칼국수) 칼국수가 참 맛나지~  \n  \n청수횟집) 생선구이 맛집이야. 여기 알면 진짜 당신도 프로 역삼러다 ㅋㅋ  \n  \n평가옥) 소고기 온반으로 점심 추천 든든 맛있음  \n  \n순남시래기) 구수한 밥상 차리고 싶은 날엔 여기지.  \n  \n\\*\\*\\*\\*일식 & 아시아식\\*\\*\\*  \n  \n갓포돈) 역삼에서 점심에 가장 줄 많이 서는 돈까스 집 중 하나! 여름에만 가능한 모밀도 맛있음!  \n  \n쁘라텟타이) 버릴 메뉴없는 동남아 음식 최고 맛집! 하지만 가격 좀 있음  \n  \n백초밥) 가성비 끝판왕 구성의 일식집 초밥 튀김 다 괜춘!  \n  \n멘야유메미루) 마제소바 (먹고싶네)  \n  \n아리네술상) 연어 덮밥 존맛탱구리지. 요즘 잘 안열어서 짜증남 ㅜ  \n  \n진가와) 우동 맛집 대기가 많아서 자주 가진 않지만 잊을 만 할 때 한 번씩 감  \n  \n호타루) 점심에 대기 안 탄 날이 없는 일식 맛집.  \n  \n\\*\\*\\*서양식\\*\\*\\*  \n  \n스매쉬 치즈 버거) 새우버거 꼭 먹어봐! 후회되면 찾아 온나  \n  \n밸런스 포케) 억지로 샐러드를 먹어야만 하는 날에 찾는 곳인데 맛있음 ㅎㅎ  \n  \n알라보) 연어구이 볼로 꼭 먹어주라!!! 멀어서 자주 못갈 뿐 여기 인정!  \n  \n바스버거) 대기가 많아 자주 가진 않지만, 이 집을 빼 놓고 버거를 논할 수는 없지!  \n  \n카페413) 점심시간 널널 할 때 브런치 메뉴 즐기러 가기 딱 놓은 곳!  \n  \n스파게티스토리) 학창 시절 학교 앞 파스타집 맛임. 오븐 크림도 먹어주라. 내가 좋아해~ ㅋㅋ  \n  \n지아니스나폴리) 도저히 뺄 수 없는 양식 맛집!  \n  \n\\*\\*\\*중식\\*\\*\\*  \n  \n차이향) 세트메뉴 구성 잘 되어 있고, 자장면 짬뽕 괜찮고 마파두부도 괜찮아!  \n  \n양궈푸 마라탕) 마라탕 초보자를 위한 사골 육수 베이스의 마라탕집! 하이디라오 좋아하면 이건 좀 다른 류의 마라탕인데 하겠지만, 또 역삼에 이만한 마라탕 집이 없다는?! ->여기 주방장님 바뀜 이젠 안감…맛없어..  \n  \n명정루) 중화국밥 맛집이라능! 불맛 좋아하는 짬뽕러버들을 위한 집이지!  \n  \n안ㅅㅂ) 더이상 맛집이 아니라는..  \n  \n웨이웨이) 우삼겹 탄탄면 꼭 먹어봐! 튀김류는 그냥 그래 ㅎㅎ 나는 추천하진 않아ㅋ  \n  \n차알) 가격대는 앞서 말한 집들에 비해 높지만, 딱 정말 미국서 먹는 중국 요리 맛이 이거구나 하는 입에 착착 감기는 맛임.\n\n![직장인끼리 소개팅하러 가기💛 by 블라인드가 만든 소개팅앱](https://d2u3dcdbebyaiu.cloudfront.net/img/action_tags/bleet.png)\n![매일 아침 7시 OPEN! 단 하루 특가 골드박스](https://d2u3dcdbebyaiu.cloudfront.net/img/action_tags/shop.png)\n\n# 공유하기\n\n### 댓글 27\n\n[해안종합건축사사무소](/kr/company/%ED%95%B4%EC%95%88%EC%A2%85%ED%95%A9%EA%B1%B4%EC%B6%95%EC%82%AC%EC%82%AC%EB%AC%B4%EC%86%8C/) ·\nq\\*\\*\\*\\*\\*\\*\\*\n\n우와 이렇게 일목요연한 맛집 공유라니 정말 유용하다ㅠㅠ 고마워!!!\n\n새회사 ·\na\\*\\*\\*\\*\\*\\*\\*\\*\n\n글쓴이) 도움이 되었다면 너무 다행이다^^\n\n작성자가 삭제한 댓글입니다.\n\n새회사 ·\na\\*\\*\\*\\*\\*\\*\\*\\*\n\n글쓴이) 나도 여기 좋아해 ㅎㅎ 넘 맛있음 ㅠㅠ 여기 비빔 칼국수도 맛있오!\n\n테이스터스 ·\n!\\*\\*\\*\\*\\*\\*\\*\\*\n\n바스버거 먹지마\n\n새회사 ·\nv\\*\\*\\*\\*\\*\\*\n *작성자*\n\n오ㅑ….??\n\n테이스터스 ·\n!\\*\\*\\*\\*\\*\\*\\*\\*\n\n장난이야 많이먹어\n\n새회사 ·\nv\\*\\*\\*\\*\\*\\*\n *작성자*\n\nㅋㅋㅋㅋ 맛집 추천해주라~~\n\nCoupang ·\n광고\n\n세스코 워터 스마트핏 직수 정수기 냉온정 방문설치\n\n작성자가 삭제한 댓글입니다.\n\n새회사 ·\na\\*\\*\\*\\*\\*\\*\\*\\*\n\n거긴 언주역이잖아 친구야…너무해. 이 글은 역삼역이라고 ㅋㅋㅋ\n\n새회사 ·\na\\*\\*\\*\\*\\*\\*\\*\\*\n\n그래 그러지뭐 ㅎ 이번 기회에 논현칼국수도 가볼게🤍\n\n[현대모비스](/kr/company/%ED%98%84%EB%8C%80%EB%AA%A8%EB%B9%84%EC%8A%A4/) ·\ni\\*\\*\\*\\*\\*\\*\\*\n\n구영회참치&초밥\n\n새회사 ·\na\\*\\*\\*\\*\\*\\*\\*\\*\n\n여기?? 음 나 여긴 좀 …ㅎㅎ 그래도 추천 고마워^^\n\n## 블라블라 추천 글\n\n### 님자 외모 6단계 중 본인은 몇단계야?\n\nㅋㅋㅋㅋ ㅠㅠ\n\n삼성SDS ·\n|\\*\\*\\*\\*\\*\n\n### 진짜 큰 맘 먹고\n\n한 10년 만에 단발함....!💇🏻\u200d♀️\n\n연세대학교의료원 ·\nl\\*\\*\\*\\*\\*\\*\\*\\*\n\n### 다들 어떤 낙으로 살아\n\n결혼은 못할거같고\n\nNH농협은행 ·\nW\\*\\*\\*\\*\\*\n\n### 예쁘려면 돈 필요한 이유\n\n일반인이니까 타고난거로는 부족해서 관리 필요하잖아\n\n우아한형제들 ·\nc\\*\\*\\*\\*\n\n### 블라 형들은 몇번이야?\n\n아무래도 1-2 갯지?\n\n하이라이트브랜즈 ·\nz\\*\\*\\*\\*\\*\n\n### 내가 32살 때 안산에서 술 먹다가 24살이랑 어쩌다 합석했는데\n\n헤어지기 직전까지 내가 연락처 안 물어보니까 자긴 나이 차이 많이 나도 만날 의향 있다.\n\ ...
#     'images': ['https://static.teamblind.com/img/web/share_topic.png',
#      'https://www.teamblind.com/kr/post/%EC%97%AD%EC%82%BC%EC%97%AD-%ED%94%84%EB%A1%9C%EC%B6%9C%EA%B7%BC%EB%9F%AC%EC%9D%98-%EC%A0%90%EC%8B%AC-%EC%B6%94%EC%B2%9C-%EB%A7%9B%EC%A7%91-%ED%92%80%EC%96%B4%EB%B3%B4%EC%95%84%EC%9A%A9%E2%98%BA%EF%B8%8F-BVD3hD3r',
#      'https://static.teamblind.com/img/www_kr/img-coupang-week-light.svg']}],
#   'response_time': 3.26,
#   'request_id': '77e7b604-92de-4018-adb7-2776a888e6e9'},
#  'answer': '역삼역 근처 맛집으로는 신동궁 감자탕 역삼본점, 빨강우산 부대찌개, 그리고 한판도가 추천됩니다. 신동궁 감자탕은 4.3의 평균 평점으로 유명하며, 빨강우산 부대찌개는 위생적으로 잘 관리된 부대찌개를 제공합니다. 한판도는 고기구이 전문점으로 인기가 많습니다.'}
